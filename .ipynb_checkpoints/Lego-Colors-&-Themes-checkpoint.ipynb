# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import csv
import datetime as dt     
from sqlalchemy import create_engine
date = dt.date.today()

# %%
# Files to Load
color_data_to_load = "lego-database/colors.csv"
theme_data_to_load = "lego-database/themes.csv"

# Read Colors and Theme Data Files and store into Pandas Data Frames
colors_data = pd.read_csv(color_data_to_load)
themes_data = pd.read_csv(theme_data_to_load)

colors_data
# Out:
#        id                          name     rgb is_trans
# 0      -1                       Unknown  0033B2        f
# 1       0                         Black  05131D        f
# 2       1                          Blue  0055BF        f
# 3       2                         Green  237841        f
# 4       3                Dark Turquoise  008F9B        f
# ..    ...                           ...     ...      ...
# 130  1004  Trans Flame Yellowish Orange  FCB76D        t
# 131  1005             Trans Fire Yellow  FBE890        t
# 132  1006        Trans Light Royal Blue  B4D4F7        t
# 133  1007                 Reddish Lilac  8E5597        f
# 134  9999                    [No Color]  05131D        f
#
# [135 rows x 4 columns]

# %%
csv_file = "../lego-database/colors.csv"
colorsreader = read_csv(csv_file)
colors_df=pd.DataFrame(colorsreader)
colors_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-df20e43a2d27> in <module>
#       1 csv_file = "../lego-database/colors.csv"
# ----> 2 colorsreader = read_csv(csv_file)
#       3 colors_df=pd.DataFrame(colorsreader)
#       4 colors_df.head()
#
# NameError: name 'read_csv' is not defined
